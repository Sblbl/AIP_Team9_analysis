# %% [markdown]
# # ADL analysis

# %% [markdown]
# In this notebook we explore the performance of Fast Downward planner on ADL problems, comparing lazy-greedy and eager-greedy search strategies, both with additive heuristic or causal graph heuristic, or both combined.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statistics import median
from math import sqrt
from numpy import mean
from scipy.stats import sem
from scipy.stats import t
from scipy.stats import wilcoxon
# %matplotlib inline
sns.set(rc={'figure.figsize':(4,4)})
sns.set_theme(style="whitegrid")

# %% [markdown]
# ## Preprocessing

# %%
df = pd.read_csv('datasets/ADL.csv', sep=';')
# merge columns
df['setup'] = df['search-strategy'] + ' ' + df['heuristic']
df['problem'] = df['domain'] + '-' + df['problem'].replace(' ', '_')
df['success'] = df['success (1-success, 0-failure)']
fails = len(df[df['success'] == 0])
perc_fails = fails / len(df.index) * 100
print('fails:', fails)
print('=', perc_fails, '% of', len(df.index))
# drop non-useful cols
df = df.drop(columns=['run-on', 'cost', 'solution-quality', 'coverage', '#', 'success (1-success, 0-failure)'])
df = df.dropna(subset=['generated'])
df = df[df.success == 1]
# correct types and format
df['generated'] = df['generated'].astype(int)
#df['length'] = df['length'].astype(int)
#df['peak-memory (KB)'] = df['peak-memory (KB)'].astype(int)
df['tot-time'] = df['tot-time'].str.replace('s', '').str.replace(',', '.')
df['tot-time'] = df['tot-time'].apply(lambda x: float(x))
df['search-time'] = df['search-time'].str.replace('s', '').str.replace(',', '.')
df['search-time'] = df['search-time'].apply(lambda x: float(x))
df['%expanded'] = df['%expanded'].str.replace(',', '.').str.replace('%', '')
df['%expanded'] = df['%expanded'].apply(lambda x: float(x)/100)
df['%used'] = df['%used'].str.replace(',', '.').str.replace('%', '')
df['%used'] = df['%used'].apply(lambda x: float(x)/100)
df.head()
# Out:
# fails: 152
# = 23.974763406940063 % of 634
#      domain              problem heuristic search-strategy  tot-time  \
# 0  din phil  din phil-instance 1       add    eager_greedy  0.010051
# 1  din phil  din phil-instance 2       add    eager_greedy  0.006933
# 2  din phil  din phil-instance 3       add    eager_greedy  0.023889
# 3  din phil  din phil-instance 4       add    eager_greedy  0.030417
# 4  din phil  din phil-instance 5       add    eager_greedy  0.037933
#
#    search-time  peak-memory (KB)  generated  evaluated  expanded  %expanded  \
# 0     0.002933           56128.0         90       82.0      41.0     0.4556
# 1     0.003034           56260.0        187      168.0      55.0     0.2941
# 2     0.017039           56272.0        404      327.0      86.0     0.2129
# 3     0.020253           56392.0        905      609.0     151.0     0.1669
# 4     0.029205           56392.0       2363     1140.0     318.0     0.1346
#
#    length   %used  dead-ends             setup  success
# 0    22.0  0.5366       20.0  eager_greedy add        1
# 1    33.0  0.6000       43.0  eager_greedy add        1
# 2    44.0  0.5116      101.0  eager_greedy add        1
# 3    55.0  0.3642      215.0  eager_greedy add        1
# 4    66.0  0.2075      458.0  eager_greedy add        1

# %% [markdown]
# ## Data Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 482 entries, 0 to 633
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   domain            482 non-null    object
#  1   problem           482 non-null    object
#  2   heuristic         482 non-null    object
#  3   search-strategy   482 non-null    object
#  4   tot-time          482 non-null    float64
#  5   search-time       482 non-null    float64
#  6   peak-memory (KB)  482 non-null    float64
#  7   generated         482 non-null    int64
#  8   evaluated         482 non-null    float64
#  9   expanded          482 non-null    float64
#  10  %expanded         482 non-null    float64
#  11  length            482 non-null    float64
#  12  %used             482 non-null    float64
#  13  dead-ends         482 non-null    float64
#  14  setup             482 non-null    object
#  15  success           482 non-null    int64
# dtypes: float64(9), int64(2), object(5)
# memory usage: 64.0+ KB

# %%
#plt.hist(df['peak-memory (KB)'], 50)
sns.distplot(df['peak-memory (KB)'])
plt.title('Distribution of memory usage in STRIPS domains')
plt.xlabel('memory')
plt.ylabel('# problems')
plt.show()
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#plt.hist(df['search-time'], 50)
sns.distplot(df['search-time'])
plt.title('Distribution of search-time in STRIPS domains')
plt.xlabel('search time')
plt.ylabel('# problems')
plt.show()
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#plt.hist(df['search-time'], 50)
sns.distplot(df['length'])
plt.title('Distribution of plan length in STRIPS domains')
plt.xlabel('plan length')
plt.ylabel('# problems')
plt.show()
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['domain'].value_counts()
# Out:
# gripper     120
# airport     116
# psr         102
# din phil     68
# elevator     40
# satelite     30
# opt tel       6
# Name: domain, dtype: int64

# %%
for domain in df['domain'].unique():
    d = df[df['domain'] == domain]
    sns.distplot(d['search-time'])
    title = domain + ' search-time distribution'
    plt.title(title)
    plt.show()
    sns.distplot(d['length'])
    title = domain + ' plan length distribution'
    plt.title(title)
    plt.show()
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Only counting how many data remained after removing the unsolved, we are able to capture the most difficult domains. For all of them we ran 20 instances for each setup, except for Optical Telegraph, for which we ran only 14 problems, because the STRIPS repo contained only that number of files.
# So, we conclude that Dining Philosopers, Optical Telegraph and PSR are very difficult to solve with a greedy approach and without helpful actions.

# %% [markdown]
# ## Analysis

# %%
lg_add = df[df.setup == 'lazy_greedy add']
lg_cg = df[df.setup == 'lazy_greedy cg']
lg_both = df[df.setup == 'lazy_greedy add+cg']
eg_add = df[df.setup == 'eager_greedy add']
eg_cg = df[df.setup == 'eager_greedy cg']
eg_both = df[df.setup == 'eager_greedy add+cg']

# %% [markdown]
# ### Functions

# %%
def get_stats(d_1, d_2):
    """
    Get the boundaries and the median of a sample
    """
    max_d1 = None
    max_d2 = None
    med_d1 = None
    med_d2 = None
    if len(d_1 > 0):
        max_d1 = d_1.max()
        med_d1 = median(d_1)
    if len(d_2 > 0):
        max_d2 = d_2.max()
        med_d2 = median(d_2)

    if max_d1 == None:
        max_d1 = max_d2
    if max_d2 == None:
        max_d2 = max_d1
        
    if med_d1 == None:
        med_d1 = med_d2
    if med_d2 == None:
        med_d2 = med_d1
        
    return {'max' : max(max_d1, max_d2), 'median' : median([med_d1, med_d2])}

# %%
def count_fails(df_1, df_2, attr, exclude=None, label_1 = 'first setup', label_2 = 'second setup'):
    """
    We count the amount of failed problems in each setup
    """
    df_1 = df_1[[attr, 'problem', 'domain']]
    df_2 = df_2[[attr, 'problem', 'domain']]
    
    #exclude domains 
    if exclude != None:
        for exc in exclude:
            df_1 = df_1[df_1['domain'] != exc]
            df_2 = df_2[df_2['domain'] != exc]
    
    p_1 = df_1.problem.unique()
    p_2 = df_2.problem.unique()
    
    unsolved_1 = 0
    unsolved_2 = 0
    
    for prob_1 in p_1:
        if prob_1 not in p_2:
            unsolved_2 += 1
    for prob_2 in p_2:
        if prob_2 not in p_1:
            unsolved_1 += 1
    return {label_1 : str('{:.2f}'.format(unsolved_1 / len(p_2)*100)) + '%',  label_2 : str('{:.2f}'.format(unsolved_2 /  len(p_1)*100)) + '%' }

# %%
def get_difference(df_1, df_2, attr, exclude=None, label_1 = 'first setup', label_2 = 'second setup'):
    """
    We count in how many cases first setup does better than 
    the second one and viceversa
    """
    df_1 = df_1[[attr, 'problem', 'domain']]
    df_2 = df_2[[attr, 'problem', 'domain']]
    
    #exclude domains 
    if exclude != None:
        for exc in exclude:
            df_1 = df_1[df_1['domain'] != exc]
            df_2 = df_2[df_2['domain'] != exc]
    
    p_1 = df_1.problem.unique()
    p_2 = df_2.problem.unique()
    
    better_1 = 0
    better_2 = 0
    
    for prob in p_1:
        if prob in p_2:
            if df_1.loc[df_1['problem'] == prob][attr].values[0] < df_2.loc[df_2['problem'] == prob][attr].values[0]:
                better_1 += 1
            else:
                better_2 += 1
        else:
            better_1 += 1
    for prob in p_2:
        if not prob in p_1:
            better_2 += 1
    
    title = attr + ' - ' + label_1 + ' vs ' + label_2
    sns.barplot(x=['better ' + label_1, 'better ' + label_2], y=[better_1, better_2])
    plt.title(title)
    plt.plot()

# %%
def plot_comparison(df_1, df_2, attr, exclude=None, label_1 = 'first setup', label_2 = 'second setup'):
    """
    Plot the performance comparison between two setups
    according to a specific attribute i.e. search-time
    """
    df_1 = df_1[[attr, 'problem', 'domain']]
    df_2 = df_2[[attr, 'problem', 'domain']]
    points = []
    seen = []
    
    for index, row in df_1.iterrows():
        datum = {}
        problem = row['problem']
        domain = row['domain']

        if len(df_2.loc[df_2['problem'] == problem][attr]) > 0:
            datum['domain'] = domain
            datum[label_1] = row[attr]
            datum[label_2] = df_2.loc[df_2['problem'] == problem][attr].values[0]
        points.append(datum)
    points = pd.DataFrame(points)

    #exclude domains 
    if exclude != None:
        for exc in exclude:
            points = points[points['domain'] != exc]
    # useful data to draw diagonal        
    max_x = points[[label_1]].max()
    max_y = points[[label_2]].max()
    max_t = max(max_x.values, max_y.values)
    
    title = attr + ' - ' + label_1 + ' vs ' + label_2
    #plot the scatter
    sc = sns.scatterplot(data=points, x=label_1, y=label_2, hue='domain', style='domain', alpha=0.5)
    sc.set(xscale='log', yscale='log')
    plt.plot([0, max_t], [0, max_t], linewidth=2)
    plt.title(title)
    plt.show()

# %%
def plot_comparison_tolerant(df_1, df_2, attr, exclude=None, label_1 = 'first setup', label_2 = 'second setup'):
    """
    Plot the performance comparison between two setups
    according to a specific attribute i.e. search-time
    """
    df_1 = df_1[[attr, 'problem', 'domain']]
    df_2 = df_2[[attr, 'problem', 'domain']]
    points = []
    seen = []
    
    for index, row in df_1.iterrows():
        datum = {}
        problem = row['problem']
        domain = row['domain']

        if len(df_2.loc[df_2['problem'] == problem][attr]) > 0:
            datum['domain'] = domain
            datum[label_1] = row[attr]
            datum[label_2] = df_2.loc[df_2['problem'] == problem][attr].values[0]
        else: 
            datum['domain'] = domain
            datum[label_1] = row[attr]
            stats = get_stats(df_1.loc[df_1['domain'] == domain][attr], df_2.loc[df_2['domain'] == domain][attr])
            #max values
            max_dt = stats['max']
            #find median values
            med_dt = stats['median']
            datum[label_2] = max_dt + med_dt #problem unsolved by first setup
        seen.append(row['problem'])
        points.append(datum)

    if len(df_2) > 0:
        for index, row in df_2.iterrows():
            domain = row['domain']
            datum = {}
            datum['domain'] = domain
            stats = get_stats(df_1.loc[df_1['domain'] == domain][attr], df_2.loc[df_2['domain'] == domain][attr])
            #max values
            max_dt = stats['max']
            #find median values
            med_dt = stats['median']
            datum[label_1] = max_dt + med_dt #problem unsolved by second setup
            datum[label_2] = row[attr]
            points.append(datum)
    points = pd.DataFrame(points)

    #exclude domains 
    if exclude != None:
        for exc in exclude:
            points = points[points['domain'] != exc]
    # useful data to draw diagonal        
    max_x = points[[label_1]].max()
    max_y = points[[label_2]].max()
    max_t = max(max_x.values, max_y.values)
    
    title = attr + ' - ' + label_1 + ' vs ' + label_2
    #plot the scatter
    sc = sns.scatterplot(data=points, x=label_1, y=label_2, hue='domain', style='domain', alpha=0.5)
    sc.set(xscale='log', yscale='log')
    plt.plot([0, max_t], [0, max_t], linewidth=2)
    plt.title(title)
    plt.show()

# %%
def wilcoxon_test(df_1, df_2, attr, exclude=None, label_1 = 'first setup', label_2 = 'second setup'):
    """
    Since we don't always have the same solved instances, 
    we have to remove the orphans and only keep the 
    problems solved by both setups
    """
    
    df_1 = df_1[[attr, 'problem', 'domain']]
    df_2 = df_2[[attr, 'problem', 'domain']]
    
    #exclude domains 
    if exclude != None:
        for exc in exclude:
            df_1 = df_1[df_1['domain'] != exc]
            df_2 = df_2[df_2['domain'] != exc]
    
    p_1 = df_1.problem.unique()
    p_2 = df_2.problem.unique()
    
    d_1 = []
    d_2 = []
    
    for prob in p_1:
        if prob in p_2:
            d_1.append(df_1.loc[df_1['problem'] == prob][attr].values[0])
            d_2.append(df_2.loc[df_2['problem'] == prob][attr].values[0])
            
    w, p = wilcoxon(d_1, d_2)
    print('w:', w, '\np:', p)
    if p > 0.05:
        print('Same distribution between', label_1, 'and', label_2, 'in terms of', attr)
    else:
        print('Significant difference between', label_1, 'and', label_2, 'in terms of', attr)

# %% [markdown]
# # Analysis of simple ADL Domains
# gripper     120 / 120
#
# airport     116 / 120
#
# psr         102 / 120

# %% [markdown]
# ## Comparison between heuristics
# The couples of setups we compare in the next cells have constant search strategy and different heuristic

# %% [markdown]
# ### Heuristics in lazy greedy

# %% [markdown]
# #### lazy greedy: add vs cg

# %% [markdown]
# Time performances

# %%
attr = 'search-time'
df_1 = lg_add
df_2 = lg_cg

plot_comparison(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add', label_2 = 'lg cg')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add', label_2 = 'lg cg')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add', label_2 = 'lg cg')
# Out:
# w: 403.0
# p: 0.009198743214382554
# Significant difference between lg add and lg cg in terms of search-time

# %% [markdown]
# plan length performance

# %%
attr = 'length'
df_1 = lg_add
df_2 = lg_cg

plot_comparison(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add', label_2 = 'lg cg')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add', label_2 = 'lg cg')
# Out:
# w: 11.5
# p: 0.003289738105933075
# Significant difference between lg add and lg cg in terms of length

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add', label_2 = 'lg cg')

# %% [markdown]
# Count of failed problems for each approach

# %%
count_fails(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add', label_2 = 'lg cg')
# Out:
# {'lg add': '1.89%', 'lg cg': '10.34%'}

# %% [markdown]
# #### lazy greedy: add vs  both

# %% [markdown]
# Time performances

# %%
attr = 'search-time'
df_1 = lg_add
df_2 = lg_both

plot_comparison(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add', label_2 = 'lg both')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add', label_2 = 'lg both')
# Out:
# w: 222.0
# p: 1.564009604975e-06
# Significant difference between lg add and lg both in terms of search-time

# %% [markdown]
# plan length performance

# %%
attr = 'length'
df_1 = lg_add
df_2 = lg_both

plot_comparison(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add', label_2 = 'lg both')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add', label_2 = 'lg both')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add', label_2 = 'lg both')
# Out:
# w: 2.0
# p: 0.04105088656045887
# Significant difference between lg add and lg both in terms of length
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2971: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %% [markdown]
# Count of failed problems for each approach

# %%
count_fails(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add', label_2 = 'lg both')
# Out:
# {'lg add': '1.72%', 'lg both': '1.72%'}

# %% [markdown]
# #### Lazy greedy: cg vs both

# %% [markdown]
# Time performances

# %%
attr = 'search-time'
df_1 = lg_cg
df_2 = lg_both

plot_comparison(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg cg', label_2 = 'lg both')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg cg', label_2 = 'lg both')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg cg', label_2 = 'lg both')
# Out:
# w: 646.0
# p: 0.8733939673227593
# Same distribution between lg cg and lg both in terms of search-time

# %% [markdown]
# plan length performance

# %%
attr = 'length'
df_1 = lg_cg
df_2 = lg_both

plot_comparison(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg cg', label_2 = 'lg both')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg cg', label_2 = 'lg both')
# Out:
# w: 11.0
# p: 0.008572797424555488
# Significant difference between lg cg and lg both in terms of length

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg cg', label_2 = 'lg both')

# %% [markdown]
# Count of failed problems for each approach

# %%
count_fails(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg cg', label_2 = 'lg both')
# Out:
# {'lg cg': '12.07%', 'lg both': '3.77%'}

# %% [markdown]
# ### Heuristics in eager greedy

# %% [markdown]
# #### eager greedy: add vs cg

# %% [markdown]
# Time performances

# %%
attr = 'search-time'
df_1 = eg_add
df_2 = eg_cg

plot_comparison(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'eg add', label_2 = 'eg cg')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'eg add', label_2 = 'eg cg')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'eg add', label_2 = 'eg cg')
# Out:
# w: 569.0
# p: 0.27446844476330645
# Same distribution between eg add and eg cg in terms of search-time

# %% [markdown]
# plan length performance

# %%
attr = 'length'
df_1 = eg_add
df_2 = eg_cg

plot_comparison(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'eg add', label_2 = 'eg cg')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'eg add', label_2 = 'eg cg')
# Out:
# w: 13.0
# p: 0.004317039847979825
# Significant difference between eg add and eg cg in terms of length

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'eg add', label_2 = 'eg cg')

# %% [markdown]
# Count of failed problems for each approach

# %%
count_fails(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'eg add', label_2 = 'eg cg')
# Out:
# {'eg add': '0.00%', 'eg cg': '10.34%'}

# %% [markdown]
# #### eager greedy: add vs  both

# %% [markdown]
# Time performances

# %%
attr = 'search-time'
df_1 = eg_add
df_2 = eg_both

plot_comparison(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'eg add', label_2 = 'eg both')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'eg add', label_2 = 'eg both')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'eg add', label_2 = 'eg both')
# Out:
# w: 110.0
# p: 7.837312739103966e-09
# Significant difference between eg add and eg both in terms of search-time

# %% [markdown]
# plan length performance

# %%
attr = 'length'
df_1 = eg_add
df_2 = eg_both

plot_comparison(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'eg add', label_2 = 'eg both')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'eg add', label_2 = 'eg both')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'eg add', label_2 = 'eg both')
# Out:
# w: 3.0
# p: 0.11183552183735439
# Same distribution between eg add and eg both in terms of length
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2971: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %% [markdown]
# Count of failed problems for each approach

# %%
count_fails(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'eg add', label_2 = 'eg both')
# Out:
# {'eg add': '1.69%', 'eg both': '0.00%'}

# %% [markdown]
# #### Eager greedy: cg vs both

# %% [markdown]
# Time performances

# %%
attr = 'search-time'
df_1 = eg_cg
df_2 = eg_both

plot_comparison(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'eg cg', label_2 = 'eg both')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'eg cg', label_2 = 'eg both')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'eg cg', label_2 = 'eg both')
# Out:
# w: 399.0
# p: 0.008266029294406545
# Significant difference between eg cg and eg both in terms of search-time

# %% [markdown]
# plan length performance

# %%
attr = 'length'
df_1 = eg_cg
df_2 = eg_both

plot_comparison(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'eg cg', label_2 = 'eg both')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'eg cg', label_2 = 'eg both')
# Out:
# w: 21.0
# p: 0.014482552336764893
# Significant difference between eg cg and eg both in terms of length

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'eg cg', label_2 = 'eg both')

# %% [markdown]
# Count of failed problems for each approach

# %%
count_fails(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'eg cg', label_2 = 'eg both')
# Out:
# {'eg cg': '11.86%', 'eg both': '0.00%'}

# %% [markdown]
# ## Comparison between search strategies
# The couples of setups we compare in the next cells have constant heuristic and different search strategy.

# %% [markdown]
# #### lazy greedy add vs eager greedy add

# %% [markdown]
# time performances

# %%
attr = 'search-time'
df_1 = lg_add
df_2 = eg_add

plot_comparison(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add', label_2 = 'eg add')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add', label_2 = 'eg add')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add', label_2 = 'eg add')
# Out:
# w: 648.0
# p: 0.10815592647484451
# Same distribution between lg add and eg add in terms of search-time

# %%
attr = 'length'
df_1 = lg_add
df_2 = eg_add

plot_comparison(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add', label_2 = 'eg add')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add', label_2 = 'eg add')
# Out:
# w: 0.0
# p: 0.0008110968155748005
# Significant difference between lg add and eg add in terms of length

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add', label_2 = 'eg add')

# %%
count_fails(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add', label_2 = 'eg add')
# Out:
# {'lg add': '0.00%', 'eg add': '0.00%'}

# %% [markdown]
# #### lazy greedy cg vs eager greedy cg

# %%
attr = 'search-time'
df_1 = lg_cg
df_2 = eg_cg

plot_comparison(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg cg', label_2 = 'eg cg')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg cg', label_2 = 'eg cg')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg cg', label_2 = 'eg cg')
# Out:
# w: 606.0
# p: 0.5931425620228769
# Same distribution between lg cg and eg cg in terms of search-time

# %%
attr = 'length'
df_1 = lg_cg
df_2 = eg_cg

plot_comparison(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg cg', label_2 = 'eg cg')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg cg', label_2 = 'eg cg')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add', label_2 = 'eg add')
# Out:
# w: 10.0
# p: 0.022334329357285493
# Significant difference between lg add and eg add in terms of length

# %%
count_fails(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg cg', label_2 = 'eg cg')
# Out:
# {'lg cg': '1.92%', 'eg cg': '3.77%'}

# %% [markdown]
# #### lg both vs eg both

# %%
attr = 'search-time'
df_1 = lg_both
df_2 = eg_both

plot_comparison(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add+cg', label_2 = 'eg add+cg')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg both', label_2 = 'eg both')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add+cg', label_2 = 'eg add+cg')
# Out:
# w: 790.0
# p: 0.6120679612671249
# Same distribution between lg add+cg and eg add+cg in terms of search-time

# %%
attr = 'length'
df_1 = lg_both
df_2 = eg_both

plot_comparison(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add+cg', label_2 = 'eg add+cg')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg both', label_2 = 'eg both')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg add+cg', label_2 = 'eg add+cg')
# Out:
# w: 3.0
# p: 0.001767508261535936
# Significant difference between lg add+cg and eg add+cg in terms of length

# %%
count_fails(df_1, df_2, attr, exclude=['din phil', 'opt tel', 'elevator', 'satelite'], label_1 = 'lg both', label_2 = 'eg both')
# Out:
# {'lg both': '1.69%', 'eg both': '0.00%'}

# %% [markdown]
# # Analysis of complex ADL Domains
#
# din phil     68 /120
#
# elevator     40 /120
#
# satelite     30 /120
#
# opt tel       6 / 84

# %% [markdown]
# ## Comparison between heuristics
# The couples of setups we compare in the next cells have constant search strategy and different heuristic

# %% [markdown]
# ### Heuristics in lazy greedy

# %% [markdown]
# #### lazy greedy: add vs cg

# %% [markdown]
# Time performances

# %%
attr = 'search-time'
df_1 = lg_add
df_2 = lg_cg

plot_comparison(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add', label_2 = 'lg cg')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add', label_2 = 'lg cg')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add', label_2 = 'lg cg')
# Out:
# w: 48.0
# p: 0.03276824951171875
# Significant difference between lg add and lg cg in terms of search-time

# %% [markdown]
# plan length performance

# %%
attr = 'length'
df_1 = lg_add
df_2 = lg_cg

plot_comparison(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add', label_2 = 'lg cg')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add', label_2 = 'lg cg')
# Out:
# w: 0.0
# p: 0.15729920705028502
# Same distribution between lg add and lg cg in terms of length
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2957: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2971: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add', label_2 = 'lg cg')

# %% [markdown]
# Count of failed problems for each approach

# %%
count_fails(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add', label_2 = 'lg cg')
# Out:
# {'lg add': '9.09%', 'lg cg': '9.09%'}

# %% [markdown]
# #### lazy greedy: add vs  both

# %% [markdown]
# Time performances

# %%
attr = 'search-time'
df_1 = lg_add
df_2 = lg_both

plot_comparison(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add', label_2 = 'lg both')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add', label_2 = 'lg both')
# Out:
# w: 0.0
# p: 4.76837158203125e-07
# Significant difference between lg add and lg both in terms of search-time

# %% [markdown]
# plan length performance

# %%
attr = 'length'
df_1 = lg_add
df_2 = lg_both

plot_comparison(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add', label_2 = 'lg both')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add', label_2 = 'lg both')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add', label_2 = 'lg both')
# Out:
# w: 1.0
# p: 0.14077277337135014
# Same distribution between lg add and lg both in terms of length
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2957: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2971: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %% [markdown]
# Count of failed problems for each approach

# %%
count_fails(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add', label_2 = 'lg both')
# Out:
# {'lg add': '8.33%', 'lg both': '0.00%'}

# %% [markdown]
# #### Lazy greedy: cg vs both

# %% [markdown]
# Time performances

# %%
attr = 'search-time'
df_1 = lg_cg
df_2 = lg_both

plot_comparison(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg cg', label_2 = 'lg both')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg cg', label_2 = 'lg both')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg cg', label_2 = 'lg both')
# Out:
# w: 96.0
# p: 0.3369474411010742
# Same distribution between lg cg and lg both in terms of search-time

# %% [markdown]
# plan length performance

# %%
attr = 'length'
df_1 = lg_cg
df_2 = lg_both

plot_comparison(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg cg', label_2 = 'lg both')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg cg', label_2 = 'lg both')
# Out:
# w: 0.0
# p: 0.06559969214707187
# Same distribution between lg cg and lg both in terms of length
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2957: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2971: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg cg', label_2 = 'lg both')

# %% [markdown]
# Count of failed problems for each approach

# %%
count_fails(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg cg', label_2 = 'lg both')
# Out:
# {'lg cg': '8.33%', 'lg both': '0.00%'}

# %% [markdown]
# ### Heuristics in eager greedy

# %% [markdown]
# #### eager greedy: add vs cg

# %% [markdown]
# Time performances

# %%
attr = 'search-time'
df_1 = eg_add
df_2 = eg_cg

plot_comparison(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'eg add', label_2 = 'eg cg')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'eg add', label_2 = 'eg cg')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'eg add', label_2 = 'eg cg')
# Out:
# w: 93.0
# p: 0.6742229461669922
# Same distribution between eg add and eg cg in terms of search-time

# %% [markdown]
# plan length performance

# %%
attr = 'length'
df_1 = eg_add
df_2 = eg_cg

plot_comparison(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'eg add', label_2 = 'eg cg')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'eg add', label_2 = 'eg cg')
# Out:
# w: 0.0
# p: 0.31731050786291415
# Same distribution between eg add and eg cg in terms of length
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2957: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2971: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'eg add', label_2 = 'eg cg')

# %% [markdown]
# Count of failed problems for each approach

# %%
count_fails(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'eg add', label_2 = 'eg cg')
# Out:
# {'eg add': '9.09%', 'eg cg': '9.09%'}

# %% [markdown]
# #### eager greedy: add vs  both

# %% [markdown]
# Time performances

# %%
attr = 'search-time'
df_1 = eg_add
df_2 = eg_both

plot_comparison(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'eg add', label_2 = 'eg both')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'eg add', label_2 = 'eg both')
# Out:
# w: 27.0
# p: 0.0023250579833984375
# Significant difference between eg add and eg both in terms of search-time

# %% [markdown]
# plan length performance

# %%
attr = 'length'
df_1 = eg_add
df_2 = eg_both

plot_comparison(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'eg add', label_2 = 'eg both')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'eg add', label_2 = 'eg both')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'eg add', label_2 = 'eg both')
# Out:
# w: 1.0
# p: 0.14077277337135014
# Same distribution between eg add and eg both in terms of length
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2957: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2971: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %% [markdown]
# Count of failed problems for each approach

# %%
count_fails(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'eg add', label_2 = 'eg both')
# Out:
# {'eg add': '9.09%', 'eg both': '9.09%'}

# %% [markdown]
# #### Eager greedy: cg vs both

# %% [markdown]
# Time performances

# %%
attr = 'search-time'
df_1 = eg_cg
df_2 = eg_both

plot_comparison(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'eg cg', label_2 = 'eg both')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'eg cg', label_2 = 'eg both')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'eg cg', label_2 = 'eg both')
# Out:
# w: 80.0
# p: 0.13748931884765625
# Same distribution between eg cg and eg both in terms of search-time

# %% [markdown]
# plan length performance

# %%
attr = 'length'
df_1 = eg_cg
df_2 = eg_both

plot_comparison(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'eg cg', label_2 = 'eg both')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'eg cg', label_2 = 'eg both')
# Out:
# w: 0.0
# p: 0.10247043485974937
# Same distribution between eg cg and eg both in terms of length
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2957: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2971: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'eg cg', label_2 = 'eg both')

# %% [markdown]
# Count of failed problems for each approach

# %%
count_fails(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'eg cg', label_2 = 'eg both')
# Out:
# {'eg cg': '0.00%', 'eg both': '0.00%'}

# %% [markdown]
# ## Comparison between search strategies
# The couples of setups we compare in the next cells have constant heuristic and different search strategy.

# %% [markdown]
# #### lazy greedy add vs eager greedy add

# %% [markdown]
# time performances

# %%
attr = 'search-time'
df_1 = lg_add
df_2 = eg_add

plot_comparison(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add', label_2 = 'eg add')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add', label_2 = 'eg add')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add', label_2 = 'eg add')
# Out:
# w: 106.0
# p: 0.5235109329223633
# Same distribution between lg add and eg add in terms of search-time

# %%
attr = 'length'
df_1 = lg_add
df_2 = eg_add

plot_comparison(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add', label_2 = 'eg add')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
try:
    wilcoxon_test(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add', label_2 = 'eg add')
except:
    print('unable to perform the test')
# Out:
# w: 1.5
# p: 0.4142161782425252
# Same distribution between lg add and eg add in terms of length
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2957: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2971: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add', label_2 = 'eg add')

# %%
count_fails(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add', label_2 = 'eg add')
# Out:
# {'lg add': '0.00%', 'eg add': '0.00%'}

# %% [markdown]
# #### lazy greedy cg vs eager greedy cg

# %%
attr = 'search-time'
df_1 = lg_cg
df_2 = eg_cg

plot_comparison(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg cg', label_2 = 'eg cg')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg cg', label_2 = 'eg cg')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg cg', label_2 = 'eg cg')
# Out:
# w: 94.0
# p: 0.30530881881713867
# Same distribution between lg cg and eg cg in terms of search-time

# %%
attr = 'length'
df_1 = lg_cg
df_2 = eg_cg

plot_comparison(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg cg', label_2 = 'eg cg')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg cg', label_2 = 'eg cg')

# %%
try:
    wilcoxon_test(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add', label_2 = 'eg add')
except:
    print('unable to perform the test')
# Out:
# w: 0.0
# p: 0.31731050786291415
# Same distribution between lg add and eg add in terms of length
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2957: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2971: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %%
count_fails(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg cg', label_2 = 'eg cg')
# Out:
# {'lg cg': '0.00%', 'eg cg': '0.00%'}

# %% [markdown]
# #### lg both vs eg both

# %%
attr = 'search-time'
df_1 = lg_both
df_2 = eg_both

plot_comparison(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add+cg', label_2 = 'eg add+cg')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg both', label_2 = 'eg both')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add+cg', label_2 = 'eg add+cg')
# Out:
# w: 115.0
# p: 0.9861344018198014
# Same distribution between lg add+cg and eg add+cg in terms of search-time
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2957: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "

# %%
attr = 'length'
df_1 = lg_both
df_2 = eg_both

plot_comparison(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add+cg', label_2 = 'eg add+cg')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# Count of how many times one setup is better than the other

# %%
get_difference(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg both', label_2 = 'eg both')

# %%
wilcoxon_test(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg add+cg', label_2 = 'eg add+cg')
# Out:
# w: 0.0
# p: 0.31731050786291415
# Same distribution between lg add+cg and eg add+cg in terms of length
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2957: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2971: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %%
count_fails(df_1, df_2, attr, exclude=['airport', 'gripper', 'psr'], label_1 = 'lg both', label_2 = 'eg both')
# Out:
# {'lg both': '0.00%', 'eg both': '8.33%'}

# %% [markdown]
# # Conclusions

# %% [markdown]
# ## For all ADL

# %%
df_add = df[df['heuristic'] == 'add']
df_cg = df[df['heuristic'] == 'cg']
df_both = df[df['heuristic'] == 'add+cg']

# %%
plot_comparison(df_add, df_cg, 'length', exclude=None, label_1 = 'additive', label_2 = 'causal graph')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
get_difference(df_add, df_cg, 'length', exclude=None, label_1 = 'additive', label_2 = 'causal graph')

# %%
count_fails(df_add, df_cg, 'length', exclude=None, label_1 = 'additive', label_2 = 'causal graph')
# Out:
# {'additive': '3.95%', 'causal graph': '8.75%'}

# %%
wilcoxon_test(df_add, df_cg, 'length', exclude=None, label_1 = 'additive', label_2 = 'causal graph')
# Out:
# w: 18.5
# p: 0.0019943877003402014
# Significant difference between additive and causal graph in terms of length

# %%
plot_comparison(df_add, df_cg, 'search-time', exclude=None, label_1 = 'additive', label_2 = 'causal graph')
wilcoxon_test(df_add, df_cg, 'search-time', exclude=None, label_1 = 'additive', label_2 = 'causal graph')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# w: 953.0
# p: 0.028868431482289725
# Significant difference between additive and causal graph in terms of search-time

# %%
get_difference(df_add, df_cg, 'search-time', exclude=None, label_1 = 'additive', label_2 = 'causal graph')
count_fails(df_add, df_cg, 'search-time', exclude=None, label_1 = 'additive', label_2 = 'causal graph')
# Out:
# {'additive': '3.95%', 'causal graph': '8.75%'}

# %%
plot_comparison(df_add, df_both, 'search-time', exclude=None, label_1 = 'additive', label_2 = 'add + cg')
wilcoxon_test(df_add, df_both, 'search-time', exclude=None, label_1 = 'additive', label_2 = 'add + cg')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# w: 364.0
# p: 1.7001461504743726e-09
# Significant difference between additive and add + cg in terms of search-time

# %%
get_difference(df_add, df_both, 'search-time', exclude=None, label_1 = 'additive', label_2 = 'add+cg')
count_fails(df_add, df_both, 'search-time', exclude=None, label_1 = 'additive', label_2 = 'add+cg')
# Out:
# {'additive': '3.61%', 'add+cg': '0.00%'}

# %% [markdown]
# ## For Simple ADL

# %%
plot_comparison(df_add, df_cg, 'length', exclude=['din phil', 'opt tel', 'psr'], label_1 = 'additive', label_2 = 'causal graph')
get_difference(df_add, df_cg, 'length', exclude=['din phil', 'opt tel', 'psr'], label_1 = 'additive', label_2 = 'causal graph')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
count_fails(df_add, df_cg, 'length', exclude=['din phil', 'opt tel', 'psr'], label_1 = 'additive', label_2 = 'causal graph')
wilcoxon_test(df_add, df_cg, 'length', exclude=['din phil', 'opt tel', 'psr'], label_1 = 'additive', label_2 = 'causal graph')
# Out:
# w: 3.0
# p: 0.016997526263810885
# Significant difference between additive and causal graph in terms of length
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:2971: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %%
count_fails(df_add, df_cg, 'length', exclude=['din phil', 'opt tel', 'psr'], label_1 = 'additive', label_2 = 'causal graph')
# Out:
# {'additive': '0.00%', 'causal graph': '4.00%'}

# %%
plot_comparison(df_add, df_cg, 'search-time', exclude=['din phil', 'opt tel', 'psr'], label_1 = 'additive', label_2 = 'causal graph')
get_difference(df_add, df_cg, 'search-time', exclude=['din phil', 'opt tel', 'psr'], label_1 = 'additive', label_2 = 'causal graph')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
wilcoxon_test(df_add, df_cg, 'search-time', exclude=['din phil', 'opt tel', 'psr'], label_1 = 'additive', label_2 = 'causal graph')
# Out:
# w: 316.0
# p: 0.005274382316261451
# Significant difference between additive and causal graph in terms of search-time

# %%
count_fails(df_add, df_cg, 'search-time', exclude=['din phil', 'opt tel', 'psr'], label_1 = 'additive', label_2 = 'causal graph')
# Out:
# {'additive': '0.00%', 'causal graph': '4.00%'}

# %%
plot_comparison(df_add, df_both, 'search-time', exclude=['din phil', 'opt tel', 'psr'], label_1 = 'additive', label_2 = 'add + cg')
wilcoxon_test(df_add, df_both, 'search-time', exclude=['din phil', 'opt tel', 'psr'], label_1 = 'additive', label_2 = 'add + cg')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# w: 166.0
# p: 5.3259507185114864e-06
# Significant difference between additive and add + cg in terms of search-time

# %%
get_difference(df_add, df_both, 'search-time', exclude=['din phil', 'opt tel', 'psr'], label_1 = 'additive', label_2 = 'add+cg')
count_fails(df_add, df_both, 'search-time', exclude=['din phil', 'opt tel', 'psr'], label_1 = 'additive', label_2 = 'add+cg')
# Out:
# {'additive': '0.00%', 'add+cg': '0.00%'}

# %%
plot_comparison(df_cg, df_both, 'search-time', exclude=['din phil', 'opt tel', 'psr'], label_1 = 'causal graph', label_2 = 'add + cg')
wilcoxon_test(df_cg, df_both, 'search-time', exclude=['din phil', 'opt tel', 'psr'], label_1 = 'causal graph', label_2 = 'add + cg')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# w: 292.0
# p: 0.0023978917789683196
# Significant difference between causal graph and add + cg in terms of search-time

# %%
count_fails(df_cg, df_both, 'search-time', exclude=['din phil', 'opt tel', 'psr'], label_1 = 'causal graph', label_2 = 'add+cg')
# Out:
# {'causal graph': '4.00%', 'add+cg': '0.00%'}

# %%
get_difference(df_cg, df_both, 'search-time', exclude=['din phil', 'opt tel', 'psr'], label_1 = 'causal graph', label_2 = 'add+cg')

# %%
df_cg['search-time'].median()
# Out:
# 0.0356234

# %% [markdown]
# ## For complex ADL

# %%
plot_comparison(df_add, df_cg, 'length', exclude=['blocks', 'gripper', 'satelite', 'logistics'], label_1 = 'additive', label_2 = 'causal graph')
get_difference(df_add, df_cg, 'length', exclude=['blocks', 'gripper', 'satelite', 'logistics'], label_1 = 'additive', label_2 = 'causal graph')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
count_fails(df_add, df_cg, 'length', exclude=['blocks', 'gripper', 'satelite', 'logistics'], label_1 = 'additive', label_2 = 'causal graph')
wilcoxon_test(df_add, df_cg, 'length', exclude=['blocks', 'gripper', 'satelite', 'logistics'], label_1 = 'additive', label_2 = 'causal graph')
# Out:
# w: 12.5
# p: 0.0023265645498803645
# Significant difference between additive and causal graph in terms of length

# %%
plot_comparison(df_add, df_cg, 'search-time', exclude=['blocks', 'gripper', 'satelite', 'logistics'], label_1 = 'additive', label_2 = 'causal graph')
get_difference(df_add, df_cg, 'search-time', exclude=['blocks', 'gripper', 'satelite', 'logistics'], label_1 = 'additive', label_2 = 'causal graph')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
wilcoxon_test(df_add, df_cg, 'search-time', exclude=['blocks', 'gripper', 'satelite', 'logistics'], label_1 = 'additive', label_2 = 'causal graph')
# Out:
# w: 414.0
# p: 0.07431991531205762
# Same distribution between additive and causal graph in terms of search-time

# %%
count_fails(df_add, df_cg, 'search-time', exclude=['blocks', 'gripper', 'satelite', 'logistics'], label_1 = 'additive', label_2 = 'causal graph')
# Out:
# {'additive': '14.29%', 'causal graph': '50.00%'}

# %%
plot_comparison(df_add, df_both, 'search-time', exclude=['blocks', 'gripper', 'satelite', 'logistics'], label_1 = 'additive', label_2 = 'add+cg')
get_difference(df_add, df_both, 'search-time', exclude=['blocks', 'gripper', 'satelite', 'logistics'], label_1 = 'additive', label_2 = 'add+cg')
# Out:
# /Users/martafioravanti/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
wilcoxon_test(df_add, df_both, 'search-time', exclude=['blocks', 'gripper', 'satelite', 'logistics'], label_1 = 'additive', label_2 = 'add+cg')
count_fails(df_add, df_both, 'search-time', exclude=['blocks', 'gripper', 'satelite', 'logistics'], label_1 = 'additive', label_2 = 'add+cg')
# Out:
# w: 233.0
# p: 6.818387598167257e-06
# Significant difference between additive and add+cg in terms of search-time
# {'additive': '5.17%', 'add+cg': '0.00%'}
